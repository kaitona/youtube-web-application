# %%
import pandas as pd
import json

from googleapiclient.discovery import build
import streamlit as st


#表示するDataFrameの行数を500までにする
pd.set_option("display.max_rows", 500)

#APIキーがまとめられているjsonファイルを読み込む
with open("secret.json") as f:
    keys = json.load(f)

#youtubeの動画検索システムをつかい、検索結果をjson形式で取得する関数
def youtube_request(youtube, query, page_token=None):
    response = youtube.search().list(
            q=query,
            part="id,snippet",
            maxResults=50,
            pageToken=page_token,
            order="relevance",
            type="video"
        ).execute()
    return response

#入力したクエリから動画を検索し、簡易的な情報をDataFrameにまとめる関数
def search_function(keys, key, recursion_count, default_df, query="python", page_token=None):
    youtube = set_developerkey(keys, key)
    try:
        response = youtube_request(youtube, query, page_token)
    except HTTPError:
        if key >= 4: st.error("本日の利用可能上限に達しました")
        key += 1
        youtube = search_function(keys, key, recursion_count, default_df, query, page_token)
    

    if "nextPageToken" in response: next_page = response["nextPageToken"]
    videos_search = response["items"]
    video_ids = [data["id"]["videoId"] for data in videos_search]

    video_list = []
    for data in videos_search:
        data_dict = {}
        data_dict["video_id"] = data["id"]["videoId"]
        data_dict["title"] = data["snippet"]["title"]
        data_dict["channel_id"] = data["snippet"]["channelId"]
        data_dict["channel_title"] = data["snippet"]["channelTitle"]
        video_list.append(data_dict)

    df_video = pd.DataFrame(video_list)
    df_video = df_formatting(df_video, "index")
    video_ids = list(df_video["video_id"])
    df_video_data = video_data(youtube, video_ids)
    results = df_formatting(create_table(df_video, df_video_data), "index")
    results = vertical_dataframe_join(default_df, results)

    if recursion_count <=0: return results
    else: return search_function(keys, key, recursion_count-1, results, query, next_page)

#search_functionで得た動画IDの配列から動画IDに対応した動画の各情報を取得し、DataFrameにまとめる関数
def video_data(youtube, video_ids):
    response = youtube.videos().list(
        id=",".join(video_ids),
        part="id,snippet,statistics"
    ).execute()

    video_items = response["items"]

    video_data = []
    for item in video_items:
        video_item = {}
        video_item["view_count"] = int(item["statistics"]["viewCount"])
        try:
            video_item["like_count"] =int(item["statistics"]["likeCount"])
        except:
            video_item["like_count"] = 0

        if video_item["like_count"] > 0:
            video_item["point"] = round(int(item["statistics"]["likeCount"])/int(item["statistics"]["viewCount"])*10**4,1)
        else:
            video_item["point"] = 0
        try:
            video_item["comment_count"] = int(item["statistics"]["commentCount"])
        except:
            video_item["comment_count"] = 0
        video_item["video_id"] = item["id"]
        video_data.append(video_item) 

    df_video_data = pd.DataFrame(video_data)
    return df_video_data

#search_functionとvideo_dataで得たDataFrameをvideo_id列で結合しcolumnsを並べ替える関数
def create_table(df_video_list, df_video_data):
    df_results = pd.merge(left=df_video_data, right=df_video_list, on="video_id")
    df_results = df_results.loc[:,
        ["video_id","title","view_count","like_count","point","comment_count","channel_id","channel_title"]]
    df_results = df_results.sort_values("point", ascending=False)
    return df_results

#DataFrameのindexを振りなおす関数
def df_formatting(df, index):
    df = df.reset_index()
    del df[f"{index}"]
    return df

#youtubeの機能を使うのにあたって必要なAPIキーなどの情報の設定を行う関数
def set_developerkey(keys, key):
    DEVELOPER_KEY = keys["KEY"][key]
    YOUTUBE_API_SERVICE_NAME = "youtube"
    YOUTUBE_API_VERSION = "v3"

    youtube = build(YOUTUBE_API_SERVICE_NAME,YOUTUBE_API_VERSION,
    developerKey=DEVELOPER_KEY)
    return youtube

#DataFrameを縦に結合する関数
def vertical_dataframe_join(df1, df2):
    return pd.concat([df1, df2])

#参照したい動画IDを入力して動画を表示する関数
def st_video_show(video_id):
    video_url = f"https://www.youtube.com/watch?v=" + video_id
    video_erea = st.empty()
    video_erea.video(video_url)

# %%
df_columns = ["video_id", "title", "view_count", "like_count", "point", "comment_count", "channel_id", "channel_title"]
default_df = pd.DataFrame(data=None, columns=df_columns)
response = search_function(keys, 0, 100/50-1, default_df, "python").sort_values("point", ascending=False)
sorted_df = df_formatting(response, "index")
# Out:
# 2022-07-22 15:55:08.048 INFO    googleapiclient.discovery_cache: file_cache is only supported with oauth2client<4.0.0
# 2022-07-22 15:55:08.924 INFO    googleapiclient.discovery_cache: file_cache is only supported with oauth2client<4.0.0

# %%
sorted_df
# Out:
#        video_id                                              title view_count  \
# 0   uOgDa1rlqjE                Python // Dicionário do Programador     103153
# 1   NS9bcrLPCxg  ضروري لكلاش L&#39;morphine - Python - Reaction...      89910
# 2   R6wNKRrKX3k  Эти ошибки совершает каждый новичок Python / 1...       7943
# 3   07Pxa3TbQc4   I learned something new about Strings in Python!      40398
# 4   MLudhcjCcLU  ये Free IIT, IBM Python Courses जीवन बदल देंगी...      29839
# 5   7CRybttp0Uc   How to use Python features from future versions!      12624
# 6   NZuNy3TzTSU           Curso de Automatización en Python [2022]      40690
# 7   qxYbHzn8bbU             5 Effective Tips to learn Python fast!     671603
# 8   MHPGeQD8TvI  How I would learn to code (if I could start over)    2676911
# 9   mRMmlo_Uqcs       you need to learn Python RIGHT NOW!! // EP 1    1029915
# 10  XKHEtdqhLK8   Python Full Course 🐍 -Learn to code today-【𝙁𝙧𝙚𝙚】    4990157
# 11  swdcD6OPMlk  Curso Completo de Python para Principiantes (2...     432644
# 12  p15xzjzR9j0  Mastering Python - Everything You Need To Know...     943633
# 13  fG9zCuZEB8I                    Why NOT to Learn Python in 2022      13444
# 14  P0czP5MEbYQ  Учим Python за 1 час! #ОтПрофессионала | HD Re...     156216
# 15  _xf1TMs0ysk  5 Unique Python Projects (beginner to intermed...     179414
# 16  5-5Mf_L0UKw  If Else Statements in Python // Python RIGHT N...     134612
# 17  qUeud6DvOWI           25 nooby Python habits you need to ditch     728165
# 18  qYhrd2Lhq0g  Introduction to Python (Hindi) | What is Pytho...      19755
# 19  Ogild8PjK6c  HOW I Learned Python in 30 Days? BEST Python C...     183764
# 20  IUZTbEaDo0U                               How To Master Python     870648
# 21  8OKTAedgFYg     11 Tips And Tricks To Write Better Python Code     390832
# 22  L5sZ6WgOnj0  Python in one video - Learn Complete Python in...     158491
# 23  7tXsC8YlCq8   Learning Python in 2 Days - Pygame Community Jam     460418
# 24  3dy_PYF9xOI  What is Python With Full Information? – [Hindi...    1321159
# 25  7iBqoc-DzTQ                 Get the Best Python Books for Free     108593
# 26  SzYKzAHsdMg                                        Python WiFi    1261054
# 27  WbBjzvP_y18  O Level Python Marathon Class 2022 | Python MC...     110355
# 28  PpLtEo3TvFw               Aprende Python para ciencia de datos     319265
# 29  27u8xHqLMZE  Complete python roadmap | How to become an exp...     734086
# 71  Z1Yd7upQsXY  Python Tutorial for Absolute Beginners #1 - Wh...    7941139
# 72  kBKn5IkH06A            【Python超入門講座】この動画1本でゼロから基礎をマスター！【初心者向け】     319393
# 73  BBu6ZoAHIwI                             Python - podstawy w 2h     581891
# 74  AWek49wXGzI  How to Use If Else Statements in Python (Pytho...    2161424
# 75  -auWrbiaoGc  Belajar Python [Dasar] - 03 - Cara Kerja Progr...     341572
# 76  WGJJIrtnfpk  Python Full Course - Learn Python in 12 Hours ...    5184843
# 77  YfO28Ihehbk                 Python for Beginners | Full Course    1359563
# 78  zdMUJJKFdsU  【python】4小時初學者Python教學 #python #python教學 #pyth...    1054339
# 79  Gh0qRBHbnVs                     【完全版】Python基礎力を圧倒的に向上させる特訓100問     421486
# 80  u-OmVr_fT4s  Python Functions | Python Tutorial for Absolut...     431542
# 81  yMOU8_hhLL8                      Python零基础入门教程5小时完整版(2020年最新版)     804092
# 82  woVJ4N5nl_s  Python Basics | Python Tutorial For Beginners ...    1031216
# 83  spX3jkOTOU8         Session 1- Python Programming for Selenium      53970
# 84  yeZ3STy3k44   【完全版】この動画1本でPythonの基礎を習得！忙しい人のための速習コース（Python入門）     553751
# 85  V49HNyAVe-M                         Pythonはなぜ人気なのか？平均年収はどれぐらい？      26467
# 86  NSbOtYzIQI0  How To Use Functions In Python (Python Tutoria...    1999158
# 87  3VmijLpHQJ0                                前端自学Python一星期，能干点啥？      12633
# 88  hSt3_2T6DMU  Python Tutorial (Farsi) - آموزش کامل برنامه نو...     269601
# 89  OMZwld35T4c                                  Pythonでできること10選+α      38362
# 90  HyU3XL2F9GE  Python超入門コース 合併版｜Pythonの超基本的な部分をたった1時間で学べます【プロ...    1452844
# 91  B2QB8gvk11g   Visual Studio Code で Python を使う（Windows のセットアップ）       2785
# 92  y-7I27ZDoEQ  Video captures moment python slips out car win...       3023
# 93  thpdTDcgPNA             Pacman Frog Python Centipede Tarantula    2653301
# 94  vRFVS_FNLwY     【ひろゆき】Pythonについて語るひろゆきまとめ【ひろゆき プログラミング言語 切り抜き】     434341
# 95  iZz4GhPRgxo  Python (2000) | Action Horror Movie | Frayne R...    9839498
# 96  RDPpZxR8ddk           【python 自動化】自動でファイル添付してOutlookメールを送信する方法        310
# 97  Ht2IsygGr98  CUTE ANIMALS Snake, Cobra, Green Snake, Golden...    4799768
# 98  dVRhRzE_AkQ      Python eats Alligator 02, Time Lapse Speed x6  155491822
# 99  xfYAj1k9uZM  Python vs Alligator  01 -- Real Fight -- Pytho...  132082374
#
#    like_count   point comment_count                channel_id  \
# 0       16076  1558.5           267  UCFuIUoyHB12qpYa8Jpxoxow
# 1        8383   932.4           588  UCZykmDCxAfp0KwwQULOW2iQ
# 2         713   897.6            68  UCA9t0ucLQLDCELE0wbDSAyw
# 3        3474   859.9            40  UCbXgNpp0jedKWcQiULLbDTA
# 4        2270   760.7            96  UCKVdr_Lro6WDKigrKQxhNlg
# 5         859   680.4            69  UCaiL2GDNpLYH6Wokkk1VNcg
# 6        2458   604.1            38  UCGKngc82bux4NIDar572E5Q
# 7       39458   587.5          2552  UCeVMnSShP_Iviwkknt83cww
# 94       2995    69.0           349  UCwhKqH0jDKm5vPOZ7WQ2R1A
# 95      39477    40.1           911  UCrKhoJu5EeWXBK5jpEj6uvw
# 96          1    32.3             0  UCQubE-5fBR6eLb62Jxn6jCw
# 97       9646    20.1            54  UCkEdsYCyC-0QrWTAD1hpjLw
# 98     231073    14.9         24955  UCyNDOuol6OIKPImq-tmePZQ
# 99     187738    14.2         16583  UCyNDOuol6OIKPImq-tmePZQ
#
#                     channel_title
# 0                 Código Fonte TV
# 1                 Familya فاميليا
# 2                  ZProger [ IT ]
# 3                 Python Engineer
# 4                          fzFact
# 5                         mCoding
# 6                  Frank Andrade
# 7                   CodeWithHarry
# 8                      Tina Huang
# 9                    NetworkChuck
# 10                       Bro Code
# 11                      Lucas Moy
# 12                  Tech With Tim
# 13          Aaron Jack / Freemote
# 14  Хауди Хо™ - Просто о мире IT!
# 15                     Tina Huang
# 16                   NetworkChuck
# 17                        mCoding
# 18                   Learn Coding
# 19                   Ishan Sharma
# 20                  Kalle Hallden
# 21                Python Engineer
# 22                    Anuj Bhaiya
# 23                       PolyMars
# 24                  Quick Support
# 25                   David Bombal
# 26                   David Bombal
# 27                   New Ideas YT
# 28         A2 Capacitación: Excel
# 29                     codebasics
# 30              Victor Robles WEB
# 31                  CodeWithHarry
# 32          Expedition Theme Park
# 33          Programming with Mosh
# 34           ProgrammingWithHarry
# 35                  CodeWithHarry
# 36                 Micro Solution
# 37                   Apna College
# 38                     ArjanCodes
# 39                  CodeWithHarry
# 40               freeCodeCamp.org
# 41              GrandmaCan -我阿嬤都會
# 42            TechWorld with Nana
# 43                  Tech With Tim
# 44                        CS Dojo
# 45          Programming with Mosh
# 46               freeCodeCamp.org
# 47                 Great Learning
# 48               freeCodeCamp.org
# 49               freeCodeCamp.org
# 50                  Tech With Tim
# 51               freeCodeCamp.org
# 52                      Afternerd
# 53            Brototype Malayalam
# 54                     Amigoscode
# 55                      Devslopes
# 56                  Simply Coding
# 57              Logic First Tamil
# 58                        Telusko
# 59          Programming with Mosh
# 60                      Rap Clips
# 61          Programming with Mosh
# 62                  Corey Schafer
# 63                  Tech With Tim
# 64               freeCodeCamp.org
# 65                 Great Learning
# 66               freeCodeCamp.org
# 67                Kevin Stratvert
# 68                    Simplilearn
# 69                        Chandoo
# 70                    WsCube Tech
# 71                        CS Dojo
# 72          セイト先生のWeb・ITエンジニア転職ラボ
# 73  Jak nauczyć się programowania
# 74                        CS Dojo
# 75                  Kelas Terbuka
# 76                       edureka!
# 77                        Telusko
# 78              GrandmaCan -我阿嬤都會
# 79                  いまにゅのプログラミング塾
# 80          Programming with Mosh
# 81                          程序员小飞
# 82                       edureka!
# 83     SDET- QA Automation Techie
# 84                  いまにゅのプログラミング塾
# 85                     エンジニアチャンネル
# 86                        CS Dojo
# 87                        小雨在烦恼什么
# 88                 Vision Academy
# 89               だれでもエンジニア / 山浦清透
# 90         キノコード / プログラミング学習チャンネル
# 91                           金子邦彦
# 92                      USA TODAY
# 93                   Nuôi Cá Cảnh
# 94                 ひろゆきキャリア【切り抜き】
# 95            Cinecurry Hollywood
# 96           じゅんぺーpython系YouTuber
# 97                      Fun Dance
# 98                         ojatro
# 99                         ojatro
